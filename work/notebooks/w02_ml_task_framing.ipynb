# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shahid-nawazai/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ### My ML Task Type
#
# My lane's ML task can be framed as a **[Classification/Clustering/Ranking/Scoring]** problem.
#
# **Justification:**
# - **Classification:** If the goal is to predict a discrete category or label (e.g., spam/not spam, churn/no churn).
# - **Clustering:** If the goal is to group similar data points together without predefined labels (e.g., customer segmentation).
# - **Ranking:** If the goal is to order items by relevance (e.g., search results, product recommendations).
# - **Scoring (Regression):** If the goal is to predict a continuous numerical value (e.g., predicted sales, risk score).
#
# *Choose one and explain why your problem fits this type, referencing the characteristics of your 'lane'.*

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ### Target or Proxy
#
# My target variable for prediction is **[Describe your target variable]**.
#
# This label comes from **[Observed outcome/Defined rule]**.
#
# **Explanation:**
# - **Observed outcome:** If the target is directly measured from real-world events (e.g., actual clicks, purchases).
# - **Defined rule:** If the target is created based on a set of logical conditions or heuristics (e.g., 'high-value customer' defined by spending over X amount).
#
# *Clearly define what you would predict and whether this label is directly observed or derived from a rule. Provide examples specific to your 'lane'.*

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ### Success Metric
#
# The primary success metric I will use to evaluate my model is **[Choose a specific metric, e.g., Accuracy, Precision, Recall, F1-Score, ROC-AUC, RMSE, MAE, R-squared, etc.]**.
#
# A 'good' value for this metric would be **[Specify a threshold or range, e.g., 'an Accuracy of 90% or higher', 'an RMSE below 0.5', 'an F1-Score of at least 0.75']**.
#
# **Justification:**
# *Explain why this specific metric is most appropriate for your business problem and ML task type. Consider the costs of different types of errors (e.g., false positives vs. false negatives) and how this metric aligns with business objectives.*

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ### The Unit of Analysis, as a Real DataFrame
#
# My unit of analysis is **[Describe what one row in your dataframe represents, e.g., 'one customer session', 'one product listing', 'one user-item interaction', 'one sensor reading']**.
#
# Below is a conceptual representation or example of what my dataframe would look like. Ideally, you would load a sample slice of your actual data here.
#
# ```python
# import pandas as pd
#
# # Replace with code to load your actual data, or create a conceptual DataFrame
# # Example for a hypothetical customer churn prediction task:
# data = {
#     'customer_id': [1, 2, 3, 4, 5],
#     'last_login_days_ago': [7, 30, 2, 60, 15],
#     'total_spend': [150.0, 50.0, 300.0, 20.0, 100.0],
#     'num_support_tickets': [1, 0, 2, 3, 0],
#     'is_churned': [0, 1, 0, 1, 0] # This is the target variable
# }
# df = pd.DataFrame(data)
#
# display(df.head())
# print(f"Each row in this DataFrame represents: a unique customer at a specific point in time.")
# ```
#
# *Replace the example code with actual data loading and a clear statement of your unit of analysis.*

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ### Why ML Beats a Fixed Rule Here
#
# Machine learning is necessary for my problem because **[Explain why a simple if-statement or set of fixed rules would be insufficient or too complex to maintain]**.
#
# Specifically, the pattern is too messy for a fixed rule due to:
#
# 1.  **High Dimensionality/Many Features:** There are too many input variables and their interactions to capture effectively with simple rules.
# 2.  **Non-linear Relationships:** The relationships between features and the target variable are not simple linear or boolean conditions.
# 3.  **Evolving Patterns:** The underlying patterns in the data change over time, requiring adaptive models that can learn from new data.
# 4.  **Implicit/Hidden Patterns:** The patterns are too subtle or complex for human experts to explicitly define as rules.
# 5.  **Unforeseen Combinations:** New situations arise that are not covered by predefined rules.
#
# *Elaborate on which of these (or other) reasons apply to your 'lane', providing concrete examples of the complexities that ML can handle better than a static, rule-based system.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
